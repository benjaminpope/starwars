# %%
from gan import gan
import matplotlib.pyplot as plt
import numpy as np

# %%
starwars = gan()
starwars.make_generator()
starwars.make_discriminator()
starwars.model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 64)                6208
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 64)                256
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 128)               512
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_4 (Dense)              (None, 96)                24672
# =================================================================
# Total params: 74,016
# Trainable params: 73,120
# Non-trainable params: 896
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 64)                6208
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 128)               8320
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 14,657
# Trainable params: 14,657
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import pandas as pd
dfile = '../notebooks/subsampled.csv'
df = pd.read_csv(dfile, sep='\s+', header=None)
df.head()
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.218025  0.327429  0.061153 -0.313490 -0.083840  0.170947  0.712686
# 1  0.383499 -0.006561 -0.451410 -0.452365 -0.148724  0.163417  0.652285
# 2  0.426076 -0.050295 -0.689354 -0.531850 -0.148613  0.141136  0.565703
# 3  0.651114 -0.085873 -0.405833 -0.704819  0.038019  0.268122  0.513000
# 4  0.850212 -0.217274  0.076044 -0.809618  0.007103  0.293927  0.552851
#
#       7         8         9        ...        16374     16375     16376  \
# 0  0.126352  0.167447  0.276619    ...    -0.164109  0.130676  0.142329
# 1  0.327991  0.324744  0.219113    ...    -0.161374 -0.516011  0.292533
# 2  0.605060  0.521936  0.218723    ...    -0.021378 -1.000000  0.404114
# 3  0.653959  0.573359  0.063392    ...    -0.257099 -0.865512  0.370643
# 4  0.568672  0.597764 -0.038057    ...    -0.023600 -0.517605  0.315868
#
#       16377     16378     16379     16380     16381     16382     16383
# 0 -0.987288 -0.567605 -0.618738 -0.216733  0.331532  0.318277  0.963297
# 1 -0.723104 -0.336234 -0.954766 -0.128803  0.444141  0.383425  0.952270
# 2 -0.376452 -0.265591 -0.966140  0.824113  0.653471  0.504843  0.929161
# 3 -0.185680 -0.301610 -0.730932 -0.106824  0.696511  1.000000  0.675593
# 4 -0.030927 -0.301473 -0.280888  0.052639  0.735776  0.848634  0.409688
#
# [5 rows x 16384 columns]

# %%
print(df.values.T.shape)
# Out:
# (16384, 96)

# %%
starwars.X_train = df.values.T

# %%
starwars.plot_some_data(nd=5)

# %%
starwars.train(epochs=200)
# Out:
# Epoch: 0 D loss: 0.8397172689437866 G loss: 1.091763973236084
# Epoch: 10 D loss: 0.6726080179214478 G loss: 0.8091784715652466
# Epoch: 20 D loss: 0.692771315574646 G loss: 0.6888301968574524
# Epoch: 30 D loss: 0.6924259066581726 G loss: 0.644869327545166
# Epoch: 40 D loss: 0.7042043209075928 G loss: 0.6674202680587769
# Epoch: 50 D loss: 0.6976032257080078 G loss: 0.6805746555328369
# Epoch: 60 D loss: 0.6986318826675415 G loss: 0.6897150278091431
# Epoch: 70 D loss: 0.694138765335083 G loss: 0.6902812719345093
# Epoch: 80 D loss: 0.6961323022842407 G loss: 0.6853578090667725
# Epoch: 90 D loss: 0.6933208703994751 G loss: 0.6898741126060486
# Epoch: 100 D loss: 0.6966421604156494 G loss: 0.6875986456871033
# Epoch: 110 D loss: 0.6952272653579712 G loss: 0.6888773441314697
# Epoch: 120 D loss: 0.6957286596298218 G loss: 0.6892150640487671
# Epoch: 130 D loss: 0.6940786838531494 G loss: 0.692283570766449
# Epoch: 140 D loss: 0.6949456930160522 G loss: 0.6919060349464417
# Epoch: 150 D loss: 0.6946883797645569 G loss: 0.6946977972984314
# Epoch: 160 D loss: 0.6943320035934448 G loss: 0.6888694167137146
# Epoch: 170 D loss: 0.6974864602088928 G loss: 0.6914568543434143
# Epoch: 180 D loss: 0.6935054063796997 G loss: 0.6956603527069092
# Epoch: 190 D loss: 0.690490186214447 G loss: 0.6928636431694031
# Epoch: 200 D loss: 0.6927521824836731 G loss: 0.692658007144928

# %%
starwars.make_img(2)
plt.show()
# Out:
# Fake images shape : (2, 96)

# %%
nd = 10
noise = starwars.noise(nd)
fake_images = starwars.gen_model.predict(noise)
print(f'Fake images shape : {fake_images.shape}')
fig, ax = plt.subplots()
ax.plot(fake_images.T)
# Out:
# Fake images shape : (10, 96)
# [<matplotlib.lines.Line2D at 0x120bfe6d8>,
#  <matplotlib.lines.Line2D at 0x120bfe828>,
#  <matplotlib.lines.Line2D at 0x120bfe978>,
#  <matplotlib.lines.Line2D at 0x120bfeac8>,
#  <matplotlib.lines.Line2D at 0x120bfec18>,
#  <matplotlib.lines.Line2D at 0x120bfed68>,
#  <matplotlib.lines.Line2D at 0x120bfeeb8>,
#  <matplotlib.lines.Line2D at 0x120bf6048>,
#  <matplotlib.lines.Line2D at 0x120bf6198>,
#  <matplotlib.lines.Line2D at 0x120bf62e8>]

# %%
fig, ax = plt.subplots()
for i in range(nd):
    ax.plot(np.abs(np.fft.rfft(fake_images[i,:]))**2, 'r-')
    ax.plot(np.abs(np.fft.rfft(starwars.X_train[i,:]))**2, 'k-')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 1e3])
# Out:
# (0.01, 1000.0)

# %%
nd = 100
noise = starwars.noise(nd)
fake_images = starwars.gen_model.predict(noise)

# %%
fig, ax = plt.subplots()
for i in range(nd):
    ax.plot(np.abs(np.fft.rfft(fake_images[i,:]))**2, 'r-')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 1e3])
# Out:
# (0.01, 1000.0)

# %%
fig, ax = plt.subplots()
for i in range(nd):
    ax.plot(np.abs(np.fft.rfft(starwars.X_train[i,:]))**2, 'k-')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 1e3])
# Out:
# (0.01, 1000.0)
