# %%
from gan import gan
import matplotlib.pyplot as plt
import numpy as np
# Out:
# /usr/local/Cellar/python3/3.6.4_2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
starwars = gan(ndays=4)
starwars.make_generator()
starwars.make_discriminator()
starwars.model()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               24704
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 128)               512
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_4 (Dense)              (None, 192)               98496
# =================================================================
# Total params: 291,392
# Trainable params: 289,600
# Non-trainable params: 1,792
# _________________________________________________________________
# None
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 128)               24704
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 128)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               33024
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 57,985
# Trainable params: 57,985
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import pandas as pd
dfile = '../notebooks/subsampled_4d.csv'
df = pd.read_csv(dfile, sep='\s+', header=None)
df.head()
# Out:
#       0         1         2         3         4         5         6      \
# 0  0.802652 -0.085702 -0.342189 -0.002655 -0.045915  0.342401  0.361984
# 1  0.397227 -0.224309 -0.045753  0.097251 -0.442355  0.130037  0.620915
# 2  0.233837  0.084215 -0.129893  0.274482 -0.538571  0.031888  0.666732
# 3  0.098603  0.410027  0.095666  0.381005 -0.083523 -0.112002  0.485105
# 4  0.256425  0.460166  0.310542  0.569557 -0.090522 -0.268609  0.063367
#
#       7         8         9        ...        16374     16375     16376  \
# 0 -0.332196  0.469128  0.659646    ...    -0.883553  0.504595  0.626793
# 1 -0.250581  0.202345  0.626363    ...    -0.916525  0.658179  0.567513
# 2 -0.095235  0.064323  0.585430    ...    -0.966727  0.711697  0.498151
# 3 -0.045208 -0.206358  0.456394    ...    -0.865246  0.446821  0.424045
# 4 -0.000617 -0.104728  0.498338    ...    -0.846916  0.138391  0.329489
#
#       16377     16378     16379     16380     16381     16382     16383
# 0 -0.440893 -0.438905 -0.395067 -0.806648 -0.396474 -0.200909 -0.203732
# 1 -0.256272 -0.311594 -0.211513 -0.895888 -0.064909 -0.004963 -0.228847
# 2 -0.358134 -0.272255 -0.246565 -0.753760  0.129942  0.155397 -0.128029
# 3 -0.030004 -0.119941 -0.195695 -0.299801  0.230101  0.524140  0.269100
# 4  0.246129 -0.086462 -0.198315  0.243549  0.168061  0.619138  0.323734
#
# [5 rows x 16384 columns]

# %%
print(df.values.T.shape)
# Out:
# (16384, 192)

# %%
starwars.X_train = df.values.T

# %%
starwars.plot_some_data(nd=2)
plt.savefig('real_time.png')

# %%
starwars.train(epochs=200)
# Out:
# Epoch: 0 D loss: 0.7086176872253418 G loss: 0.6952491998672485
# Epoch: 10 D loss: 0.6066547632217407 G loss: 0.9071505069732666
# Epoch: 20 D loss: 0.6991850137710571 G loss: 0.5927985310554504
# Epoch: 30 D loss: 0.705308198928833 G loss: 0.656284511089325
# Epoch: 40 D loss: 0.6951439380645752 G loss: 0.6721161603927612
# Epoch: 50 D loss: 0.692937433719635 G loss: 0.6857520937919617
# Epoch: 60 D loss: 0.6948069334030151 G loss: 0.6869603991508484
# Epoch: 70 D loss: 0.6951150894165039 G loss: 0.6916278004646301
# Epoch: 80 D loss: 0.6945015788078308 G loss: 0.6873217225074768
# Epoch: 90 D loss: 0.691663384437561 G loss: 0.6950640678405762
# Epoch: 100 D loss: 0.6941481828689575 G loss: 0.6945457458496094
# Epoch: 110 D loss: 0.695313572883606 G loss: 0.6863945126533508
# Epoch: 120 D loss: 0.6946593523025513 G loss: 0.6871109008789062
# Epoch: 130 D loss: 0.6927585601806641 G loss: 0.6985928416252136
# Epoch: 140 D loss: 0.6948820948600769 G loss: 0.6937444806098938
# Epoch: 150 D loss: 0.6924365758895874 G loss: 0.6908338665962219
# Epoch: 160 D loss: 0.6950127482414246 G loss: 0.6934583187103271
# Epoch: 170 D loss: 0.6938924789428711 G loss: 0.6907846331596375
# Epoch: 180 D loss: 0.692747950553894 G loss: 0.6942830085754395
# Epoch: 190 D loss: 0.6932058930397034 G loss: 0.6952772736549377
# Epoch: 200 D loss: 0.6931650638580322 G loss: 0.6919994354248047

# %%
starwars.make_img(2)
plt.savefig('fake_time.png')
plt.show()
# Out:
# Fake images shape : (2, 192)

# %%
nd = 2
noise = starwars.noise(nd)
fake_images = starwars.gen_model.predict(noise)
print(f'Fake images shape : {fake_images.shape}')
fig, ax = plt.subplots()
ax.plot(fake_images.T)
# Out:
# Fake images shape : (2, 192)
# [<matplotlib.lines.Line2D at 0x120ad82e8>,
#  <matplotlib.lines.Line2D at 0x120ad8438>]

# %%
fig, ax = plt.subplots()
for i in range(nd):
    ax.plot(np.abs(np.fft.rfft(fake_images[i,:]))**2, 'r-')
    ax.plot(np.abs(np.fft.rfft(starwars.X_train[i,:]))**2, 'k-')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 1e3])
fig.savefig('both_f.png')

# %%
nd = 1000
noise = starwars.noise(nd)
fake_images = starwars.gen_model.predict(noise)

# %%
fig, ax = plt.subplots()
for i in range(nd):
    ax.plot(np.abs(np.fft.rfft(fake_images[i,:]))**2, 'r-')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 1e4])
fig.savefig('fake_f.png')

# %%
fig, ax = plt.subplots()
for i in range(nd):
    ax.plot(np.abs(np.fft.rfft(starwars.X_train[i,:]))**2, 'k-')
ax.set_xscale('log')
ax.set_yscale('log')
ax.set_ylim([0.01, 1e4])
fig.savefig('real_p.png')
